# %% [markdown]
# # Project 2: Case Studies
#
# ## World Happiness Report
#
# By Preethi Susan Abraham and Alvin Varghese

# %%
#Loading the packages
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

# %% [markdown]
# # Background
#
# The datasets below are obtained from Kaggle. These datasets contain information about the happiness score and rank for several countries along with various other parameters like GDP per Capita, Family, Life Expectancy, Freedom, Generosity, Trust Government Corruption etc which contributes towards the happiness score.
#
# The main aim is to understand which factors are contributing to the hapinesss score the most. Here, we will also feed in our own data as per our intuition to check whether our model gives us right results.
#
# Note: The happiness score is out of 10

# %%
#Reading the data for years 2015-2019
data_2015=pd.read_csv("C:/Users/Preethi Abraham/Desktop/Brandeis Studies/Big Data 2/datasets/notebooks/Assignment 3/World Happiness/2015.csv")
data_2016=pd.read_csv("C:/Users/Preethi Abraham/Desktop/Brandeis Studies/Big Data 2/datasets/notebooks/Assignment 3/World Happiness/2016.csv")
data_2017=pd.read_csv("C:/Users/Preethi Abraham/Desktop/Brandeis Studies/Big Data 2/datasets/notebooks/Assignment 3/World Happiness/2017.csv")
data_2018=pd.read_csv("C:/Users/Preethi Abraham/Desktop/Brandeis Studies/Big Data 2/datasets/notebooks/Assignment 3/World Happiness/2018.csv")
data_2019=pd.read_csv("C:/Users/Preethi Abraham/Desktop/Brandeis Studies/Big Data 2/datasets/notebooks/Assignment 3/World Happiness/2019.csv")

# %%
data_2015.head()
# Out:
#        Country          Region  Happiness Rank  Happiness Score  \
# 0  Switzerland  Western Europe               1            7.587
# 1      Iceland  Western Europe               2            7.561
# 2      Denmark  Western Europe               3            7.527
# 3       Norway  Western Europe               4            7.522
# 4       Canada   North America               5            7.427
#
#    Standard Error  Economy (GDP per Capita)   Family  \
# 0         0.03411                   1.39651  1.34951
# 1         0.04884                   1.30232  1.40223
# 2         0.03328                   1.32548  1.36058
# 3         0.03880                   1.45900  1.33095
# 4         0.03553                   1.32629  1.32261
#
#    Health (Life Expectancy)  Freedom  Trust (Government Corruption)  \
# 0                   0.94143  0.66557                        0.41978
# 1                   0.94784  0.62877                        0.14145
# ...

# %%
data_2016.head()
# Out:
#        Country          Region  Happiness Rank  Happiness Score  \
# 0      Denmark  Western Europe               1            7.526
# 1  Switzerland  Western Europe               2            7.509
# 2      Iceland  Western Europe               3            7.501
# 3       Norway  Western Europe               4            7.498
# 4      Finland  Western Europe               5            7.413
#
#    Lower Confidence Interval  Upper Confidence Interval  \
# 0                      7.460                      7.592
# 1                      7.428                      7.590
# 2                      7.333                      7.669
# 3                      7.421                      7.575
# 4                      7.351                      7.475
#
#    Economy (GDP per Capita)   Family  Health (Life Expectancy)  Freedom  \
# 0                   1.44178  1.16374                   0.79504  0.57941
# 1                   1.52733  1.14524                   0.86303  0.58557
# ...

# %%
data_2017.head()
# Out:
#        Country  Happiness.Rank  Happiness.Score  Whisker.high  Whisker.low  \
# 0       Norway               1            7.537      7.594445     7.479556
# 1      Denmark               2            7.522      7.581728     7.462272
# 2      Iceland               3            7.504      7.622030     7.385970
# 3  Switzerland               4            7.494      7.561772     7.426227
# 4      Finland               5            7.469      7.527542     7.410458
#
#    Economy..GDP.per.Capita.    Family  Health..Life.Expectancy.   Freedom  \
# 0                  1.616463  1.533524                  0.796667  0.635423
# 1                  1.482383  1.551122                  0.792566  0.626007
# 2                  1.480633  1.610574                  0.833552  0.627163
# 3                  1.564980  1.516912                  0.858131  0.620071
# 4                  1.443572  1.540247                  0.809158  0.617951
#
#    Generosity  Trust..Government.Corruption.  Dystopia.Residual
# ...

# %%
data_2018.head()
# Out:
#    Overall rank Country or region  Score  GDP per capita  Social support  \
# 0             1           Finland  7.632           1.305           1.592
# 1             2            Norway  7.594           1.456           1.582
# 2             3           Denmark  7.555           1.351           1.590
# 3             4           Iceland  7.495           1.343           1.644
# 4             5       Switzerland  7.487           1.420           1.549
#
#    Healthy life expectancy  Freedom to make life choices  Generosity  \
# 0                    0.874                         0.681       0.202
# 1                    0.861                         0.686       0.286
# 2                    0.868                         0.683       0.284
# 3                    0.914                         0.677       0.353
# 4                    0.927                         0.660       0.256
#
#    Perceptions of corruption
# 0                      0.393
# 1                      0.340
# ...

# %%
data_2019.head()
# Out:
#    Overall rank Country or region  Score  GDP per capita  Social support  \
# 0             1           Finland  7.769           1.340           1.587
# 1             2           Denmark  7.600           1.383           1.573
# 2             3            Norway  7.554           1.488           1.582
# 3             4           Iceland  7.494           1.380           1.624
# 4             5       Netherlands  7.488           1.396           1.522
#
#    Healthy life expectancy  Freedom to make life choices  Generosity  \
# 0                    0.986                         0.596       0.153
# 1                    0.996                         0.592       0.252
# 2                    1.028                         0.603       0.271
# 3                    1.026                         0.591       0.354
# 4                    0.999                         0.557       0.322
#
#    Perceptions of corruption
# 0                      0.393
# 1                      0.410
# ...

# %% [markdown]
# The columns which are common in all 5 datasets are:
# 1. Country
# 2. Happiness.Rank/ Overall Rank
# 3. Happiness Score/ Score
# 4. Economy..GDP.per.Capita./ GDP per capita
# 5. Freedom/ Freedom to make life choices
# 6. Generosity
# 7. Perceptions of corruption/ Trust..Government.Corruption.
# 8. Family/ Social support

# %% [markdown]
# # Cleaning up the datasets and merging them into a single dataframe

# %%
#Add the year column to each dataset
data_2015["Year"]=2015
data_2015.head()
# Out:
#        Country          Region  Happiness Rank  Happiness Score  \
# 0  Switzerland  Western Europe               1            7.587
# 1      Iceland  Western Europe               2            7.561
# 2      Denmark  Western Europe               3            7.527
# 3       Norway  Western Europe               4            7.522
# 4       Canada   North America               5            7.427
#
#    Standard Error  Economy (GDP per Capita)   Family  \
# 0         0.03411                   1.39651  1.34951
# 1         0.04884                   1.30232  1.40223
# 2         0.03328                   1.32548  1.36058
# 3         0.03880                   1.45900  1.33095
# 4         0.03553                   1.32629  1.32261
#
#    Health (Life Expectancy)  Freedom  Trust (Government Corruption)  \
# 0                   0.94143  0.66557                        0.41978
# 1                   0.94784  0.62877                        0.14145
# ...

# %%
data_2016["Year"]=2016
data_2016.head()
# Out:
#        Country          Region  Happiness Rank  Happiness Score  \
# 0      Denmark  Western Europe               1            7.526
# 1  Switzerland  Western Europe               2            7.509
# 2      Iceland  Western Europe               3            7.501
# 3       Norway  Western Europe               4            7.498
# 4      Finland  Western Europe               5            7.413
#
#    Lower Confidence Interval  Upper Confidence Interval  \
# 0                      7.460                      7.592
# 1                      7.428                      7.590
# 2                      7.333                      7.669
# 3                      7.421                      7.575
# 4                      7.351                      7.475
#
#    Economy (GDP per Capita)   Family  Health (Life Expectancy)  Freedom  \
# 0                   1.44178  1.16374                   0.79504  0.57941
# 1                   1.52733  1.14524                   0.86303  0.58557
# ...

# %%
data_2017["Year"]=2017
data_2018["Year"]=2018
data_2019["Year"]=2019

# %%
# Rename columns so that there will be consistency when it is time to merge the datasets

data_2015.rename(columns={"Happiness Rank": "HappinessRank", 
                         "Happiness Score": "HappinessScore", 
                         "Economy (GDP per Capita)": "GDP", 
                         "Health (Life Expectancy)": "Life", 
                         "Trust (Government Corruption)": "Trust"}, inplace = True)
data_2015.head()
# Out:
#        Country          Region  HappinessRank  HappinessScore  Standard Error  \
# 0  Switzerland  Western Europe              1           7.587         0.03411
# 1      Iceland  Western Europe              2           7.561         0.04884
# 2      Denmark  Western Europe              3           7.527         0.03328
# 3       Norway  Western Europe              4           7.522         0.03880
# 4       Canada   North America              5           7.427         0.03553
#
#        GDP   Family     Life  Freedom    Trust  Generosity  Dystopia Residual  \
# 0  1.39651  1.34951  0.94143  0.66557  0.41978     0.29678            2.51738
# 1  1.30232  1.40223  0.94784  0.62877  0.14145     0.43630            2.70201
# 2  1.32548  1.36058  0.87464  0.64938  0.48357     0.34139            2.49204
# 3  1.45900  1.33095  0.88521  0.66973  0.36503     0.34699            2.46531
# 4  1.32629  1.32261  0.90563  0.63297  0.32957     0.45811            2.45176
#
#    Year
# 0  2015
# 1  2015
# ...

# %%
data_2016.rename(columns={"Happiness Rank": "HappinessRank", 
                         "Happiness Score": "HappinessScore", 
                         "Economy (GDP per Capita)": "GDP", 
                         "Health (Life Expectancy)": "Life", 
                         "Trust (Government Corruption)": "Trust"}, inplace = True)
data_2016.head()
# Out:
#        Country          Region  HappinessRank  HappinessScore  \
# 0      Denmark  Western Europe              1           7.526
# 1  Switzerland  Western Europe              2           7.509
# 2      Iceland  Western Europe              3           7.501
# 3       Norway  Western Europe              4           7.498
# 4      Finland  Western Europe              5           7.413
#
#    Lower Confidence Interval  Upper Confidence Interval      GDP   Family  \
# 0                      7.460                      7.592  1.44178  1.16374
# 1                      7.428                      7.590  1.52733  1.14524
# 2                      7.333                      7.669  1.42666  1.18326
# 3                      7.421                      7.575  1.57744  1.12690
# 4                      7.351                      7.475  1.40598  1.13464
#
#       Life  Freedom    Trust  Generosity  Dystopia Residual  Year
# 0  0.79504  0.57941  0.44453     0.36171            2.73939  2016
# ...

# %%
data_2017.rename(columns={"Happiness.Rank": "HappinessRank", 
                         "Happiness.Score": "HappinessScore", 
                         "Economy..GDP.per.Capita.": "GDP", 
                         "Health..Life.Expectancy.": "Life",
                         "Trust..Government.Corruption.": "Trust"}, inplace = True)
data_2017.head()
# Out:
#        Country  HappinessRank  HappinessScore  Whisker.high  Whisker.low  \
# 0       Norway              1           7.537      7.594445     7.479556
# 1      Denmark              2           7.522      7.581728     7.462272
# 2      Iceland              3           7.504      7.622030     7.385970
# 3  Switzerland              4           7.494      7.561772     7.426227
# 4      Finland              5           7.469      7.527542     7.410458
#
#         GDP    Family      Life   Freedom  Generosity     Trust  \
# 0  1.616463  1.533524  0.796667  0.635423    0.362012  0.315964
# 1  1.482383  1.551122  0.792566  0.626007    0.355280  0.400770
# 2  1.480633  1.610574  0.833552  0.627163    0.475540  0.153527
# 3  1.564980  1.516912  0.858131  0.620071    0.290549  0.367007
# 4  1.443572  1.540247  0.809158  0.617951    0.245483  0.382612
#
#    Dystopia.Residual  Year
# 0           2.277027  2017
# 1           2.313707  2017
# 2           2.322715  2017
# ...

# %%
data_2018.rename(columns={"Overall rank": "HappinessRank", 
                         "Country or region": "Country", 
                         "Score": "HappinessScore", 
                         "GDP per capita": "GDP", 
                         "Social support": "Family",
                         "Healthy life expectancy": "Life", 
                         "Freedom to make life choices": "Freedom",
                         "Perceptions of corruption": "Trust"}, inplace = True)
data_2018.head()
# Out:
#    HappinessRank      Country  HappinessScore    GDP  Family   Life  Freedom  \
# 0              1      Finland           7.632  1.305   1.592  0.874    0.681
# 1              2       Norway           7.594  1.456   1.582  0.861    0.686
# 2              3      Denmark           7.555  1.351   1.590  0.868    0.683
# 3              4      Iceland           7.495  1.343   1.644  0.914    0.677
# 4              5  Switzerland           7.487  1.420   1.549  0.927    0.660
#
#    Generosity  Trust  Year
# 0       0.202  0.393  2018
# 1       0.286  0.340  2018
# 2       0.284  0.408  2018
# 3       0.353  0.138  2018
# 4       0.256  0.357  2018

# %%
data_2019.rename(columns={"Overall rank": "HappinessRank", 
                         "Country or region": "Country", 
                         "Score": "HappinessScore", 
                         "GDP per capita": "GDP", 
                         "Social support": "Family",
                         "Healthy life expectancy": "Life", 
                         "Freedom to make life choices": "Freedom",
                         "Perceptions of corruption": "Trust"}, inplace = True)
data_2019.head()
# Out:
#    HappinessRank      Country  HappinessScore    GDP  Family   Life  Freedom  \
# 0              1      Finland           7.769  1.340   1.587  0.986    0.596
# 1              2      Denmark           7.600  1.383   1.573  0.996    0.592
# 2              3       Norway           7.554  1.488   1.582  1.028    0.603
# 3              4      Iceland           7.494  1.380   1.624  1.026    0.591
# 4              5  Netherlands           7.488  1.396   1.522  0.999    0.557
#
#    Generosity  Trust  Year
# 0       0.153  0.393  2019
# 1       0.252  0.410  2019
# 2       0.271  0.341  2019
# 3       0.354  0.118  2019
# 4       0.322  0.298  2019

# %%
#Dropping the unneccesarry columns from each dataset so that every dataset has the same number of columns

data_2015.drop(["Region","Dystopia Residual", "Standard Error"], axis = 1, inplace = True)
data_2016.drop(["Region","Lower Confidence Interval", "Upper Confidence Interval", "Dystopia Residual"], axis = 1, inplace = True)
data_2017.drop(["Whisker.high", "Whisker.low", "Dystopia.Residual"], axis = 1, inplace = True)

# %%
data_2015.head()
# Out:
#        Country  HappinessRank  HappinessScore      GDP   Family     Life  \
# 0  Switzerland              1           7.587  1.39651  1.34951  0.94143
# 1      Iceland              2           7.561  1.30232  1.40223  0.94784
# 2      Denmark              3           7.527  1.32548  1.36058  0.87464
# 3       Norway              4           7.522  1.45900  1.33095  0.88521
# 4       Canada              5           7.427  1.32629  1.32261  0.90563
#
#    Freedom    Trust  Generosity  Year
# 0  0.66557  0.41978     0.29678  2015
# 1  0.62877  0.14145     0.43630  2015
# 2  0.64938  0.48357     0.34139  2015
# 3  0.66973  0.36503     0.34699  2015
# 4  0.63297  0.32957     0.45811  2015

# %%
data_2016.head()
# Out:
#        Country  HappinessRank  HappinessScore      GDP   Family     Life  \
# 0      Denmark              1           7.526  1.44178  1.16374  0.79504
# 1  Switzerland              2           7.509  1.52733  1.14524  0.86303
# 2      Iceland              3           7.501  1.42666  1.18326  0.86733
# 3       Norway              4           7.498  1.57744  1.12690  0.79579
# 4      Finland              5           7.413  1.40598  1.13464  0.81091
#
#    Freedom    Trust  Generosity  Year
# 0  0.57941  0.44453     0.36171  2016
# 1  0.58557  0.41203     0.28083  2016
# 2  0.56624  0.14975     0.47678  2016
# 3  0.59609  0.35776     0.37895  2016
# 4  0.57104  0.41004     0.25492  2016

# %%
data_2017.head()
# Out:
#        Country  HappinessRank  HappinessScore       GDP    Family      Life  \
# 0       Norway              1           7.537  1.616463  1.533524  0.796667
# 1      Denmark              2           7.522  1.482383  1.551122  0.792566
# 2      Iceland              3           7.504  1.480633  1.610574  0.833552
# 3  Switzerland              4           7.494  1.564980  1.516912  0.858131
# 4      Finland              5           7.469  1.443572  1.540247  0.809158
#
#     Freedom  Generosity     Trust  Year
# 0  0.635423    0.362012  0.315964  2017
# 1  0.626007    0.355280  0.400770  2017
# 2  0.627163    0.475540  0.153527  2017
# 3  0.620071    0.290549  0.367007  2017
# 4  0.617951    0.245483  0.382612  2017

# %%
data_2018.head()
# Out:
#    HappinessRank      Country  HappinessScore    GDP  Family   Life  Freedom  \
# 0              1      Finland           7.632  1.305   1.592  0.874    0.681
# 1              2       Norway           7.594  1.456   1.582  0.861    0.686
# 2              3      Denmark           7.555  1.351   1.590  0.868    0.683
# 3              4      Iceland           7.495  1.343   1.644  0.914    0.677
# 4              5  Switzerland           7.487  1.420   1.549  0.927    0.660
#
#    Generosity  Trust  Year
# 0       0.202  0.393  2018
# 1       0.286  0.340  2018
# 2       0.284  0.408  2018
# 3       0.353  0.138  2018
# 4       0.256  0.357  2018

# %%
data_2019.head()
# Out:
#    HappinessRank      Country  HappinessScore    GDP  Family   Life  Freedom  \
# 0              1      Finland           7.769  1.340   1.587  0.986    0.596
# 1              2      Denmark           7.600  1.383   1.573  0.996    0.592
# 2              3       Norway           7.554  1.488   1.582  1.028    0.603
# 3              4      Iceland           7.494  1.380   1.624  1.026    0.591
# 4              5  Netherlands           7.488  1.396   1.522  0.999    0.557
#
#    Generosity  Trust  Year
# 0       0.153  0.393  2019
# 1       0.252  0.410  2019
# 2       0.271  0.341  2019
# 3       0.354  0.118  2019
# 4       0.322  0.298  2019

# %%
data_final = pd.concat([data_2015, data_2016, data_2017, data_2018, data_2019]).reset_index()
data_final
# Out:
#      index                   Country  HappinessRank  HappinessScore      GDP  \
# 0        0               Switzerland              1           7.587  1.39651
# 1        1                   Iceland              2           7.561  1.30232
# 2        2                   Denmark              3           7.527  1.32548
# 3        3                    Norway              4           7.522  1.45900
# 4        4                    Canada              5           7.427  1.32629
# ..     ...                       ...            ...             ...      ...
# 777    151                    Rwanda            152           3.334  0.35900
# 778    152                  Tanzania            153           3.231  0.47600
# 779    153               Afghanistan            154           3.203  0.35000
# 780    154  Central African Republic            155           3.083  0.02600
# 781    155               South Sudan            156           2.853  0.30600
#
# ...

# %%
data_final.drop(["index"], axis = 1, inplace = True)
data_final
# Out:
#                       Country  HappinessRank  HappinessScore      GDP  \
# 0                 Switzerland              1           7.587  1.39651
# 1                     Iceland              2           7.561  1.30232
# 2                     Denmark              3           7.527  1.32548
# 3                      Norway              4           7.522  1.45900
# 4                      Canada              5           7.427  1.32629
# ..                        ...            ...             ...      ...
# 777                    Rwanda            152           3.334  0.35900
# 778                  Tanzania            153           3.231  0.47600
# 779               Afghanistan            154           3.203  0.35000
# 780  Central African Republic            155           3.083  0.02600
# 781               South Sudan            156           2.853  0.30600
#
#       Family     Life  Freedom    Trust  Generosity  Year
# 0    1.34951  0.94143  0.66557  0.41978     0.29678  2015
# ...

# %% [markdown]
# # Exploratory Data Analysis

# %%
data_final.describe()
# Out:
#        HappinessRank  HappinessScore         GDP      Family        Life  \
# count     782.000000      782.000000  782.000000  782.000000  782.000000
# mean       78.698210        5.379018    0.916047    1.078392    0.612416
# std        45.182384        1.127456    0.407340    0.329548    0.248309
# min         1.000000        2.693000    0.000000    0.000000    0.000000
# 25%        40.000000        4.509750    0.606500    0.869363    0.440183
# 50%        79.000000        5.322000    0.982205    1.124735    0.647310
# 75%       118.000000        6.189500    1.236187    1.327250    0.808000
# max       158.000000        7.769000    2.096000    1.644000    1.141000
#
#           Freedom       Trust  Generosity         Year
# count  782.000000  781.000000  782.000000   782.000000
# mean     0.411091    0.125436    0.218576  2016.993606
# std      0.152880    0.105816    0.122321     1.417364
# min      0.000000    0.000000    0.000000  2015.000000
# ...

# %%
sns.set_style("darkgrid")
plt.figure(figsize = (7,5))
fig, axes = plt.subplots(1, 4, figsize=(15, 5), sharey=True)
sns.boxplot(ax=axes[0],data=data_final, x='Year', y='HappinessScore')
axes[0].set_title('Boxplot for HappinessScore for each year ')
sns.boxplot(ax=axes[1],data=data_final, x='Year', y='GDP')
axes[1].set_title('Boxplot for GDP for each year ')
sns.boxplot(ax=axes[2],data=data_final, x='Year', y='Family')
axes[2].set_title('Boxplot for Family for each year ')
sns.boxplot(ax=axes[3],data=data_final, x='Year', y='Life')
axes[3].set_title('Boxplot for Life for each year ')
# Out:
# Text(0.5, 1.0, 'Boxplot for Life for each year ')

# %%
fig, axes = plt.subplots(1, 3, figsize=(15, 5), sharey=True)
sns.boxplot(ax=axes[0],data=data_final, x='Year', y='Freedom')
axes[0].set_title('Boxplot for Freedom for each year ')
sns.boxplot(ax=axes[1],data=data_final, x='Year', y='Trust')
axes[1].set_title('Boxplot for Trust for each year ')
sns.boxplot(ax=axes[2],data=data_final, x='Year', y='Generosity')
axes[2].set_title('Boxplot for Generosity for each year ')
# Out:
# Text(0.5, 1.0, 'Boxplot for Generosity for each year ')

# %%
#Heatmap
plt.figure(figsize = (10,7))
sns.heatmap(data_final.corr(),cmap="coolwarm",annot = True)

# %%
fig, axes = plt.subplots(1, 3, figsize=(15, 5), sharey=True)
sns.scatterplot(ax=axes[0],data=data_final, x='GDP', y='HappinessScore')
axes[0].set_title('GDP vs HappinessScore ')
sns.scatterplot(ax=axes[1],data=data_final, x='Family', y='HappinessScore')
axes[1].set_title('Family vs HappinessScore ')
sns.scatterplot(ax=axes[2],data=data_final, x='Life', y='HappinessScore')
axes[2].set_title('Life vs HappinessScore ')

#GDP Range: 0 to 2.096
#Family Range: 0 to 1.64
#Life Range: 0 to 1.141

#As the GDP values get higher, the happiness score also becomes higher. ( countries with GDP of approx 1.2 or greater seem to have a higher happiness score)
#As the Family values get higher, the happiness score also becomes higher. ( countries with GDP of approx 1 or greater seem to have a higher happiness score)
#As the Life values get higher, the happiness score also becomes higher. ( countries with GDP of approx 0.8 or greater seem to have a higher happiness score)
# Out:
# Text(0.5, 1.0, 'Life vs HappinessScore ')

# %%
fig, axes = plt.subplots(1, 3, figsize=(15, 5), sharey=True)
sns.scatterplot(ax=axes[0],data=data_final, x='Freedom', y='HappinessScore')
axes[0].set_title('Freedom vs HappinessScore ')
sns.scatterplot(ax=axes[1],data=data_final, x='Trust', y='HappinessScore')
axes[1].set_title('Trust vs HappinessScore ')
sns.scatterplot(ax=axes[2],data=data_final, x='Generosity', y='HappinessScore')
axes[2].set_title('Generosity vs HappinessScore ')

#Freedom Range: 0 to 0.7
#Trust Range: 0 to 0.55
#Generosity Range: 0 to 0.83

#It can be seen that trust and generosity do not seem to have too much effect on happiness score

#As the Freedom values get higher, the happiness score also becomes higher. ( countries with Freedom of approx 0.35 or greater seem to have a higher happiness score)
#Trust scores do not seem to be impacting Happiness scores to a great extent (countries with Trust of approx 0.1 to 0.2 seem to have a higher happiness score)
#Generosity scores do not seem to be impacting Happiness scores to a great extent (countries with Generosity of approx 0.2 to 0.4 seem to have a higher happiness score)
# Out:
# Text(0.5, 1.0, 'Generosity vs HappinessScore ')

# %%
#Try to analyze just the contries who have scored a rank of upto 5 (The happiest countries)
countries_with_ranking_upto_5=data_final[data_final['HappinessRank']<=5]

# %%
countries_with_ranking_upto_5
# Out:
#          Country  HappinessRank  HappinessScore       GDP    Family      Life  \
# 0    Switzerland              1           7.587  1.396510  1.349510  0.941430
# 1        Iceland              2           7.561  1.302320  1.402230  0.947840
# 2        Denmark              3           7.527  1.325480  1.360580  0.874640
# 3         Norway              4           7.522  1.459000  1.330950  0.885210
# 4         Canada              5           7.427  1.326290  1.322610  0.905630
# 158      Denmark              1           7.526  1.441780  1.163740  0.795040
# 159  Switzerland              2           7.509  1.527330  1.145240  0.863030
# 160      Iceland              3           7.501  1.426660  1.183260  0.867330
# 161       Norway              4           7.498  1.577440  1.126900  0.795790
# 162      Finland              5           7.413  1.405980  1.134640  0.810910
# 315       Norway              1           7.537  1.616463  1.533524  0.796667
# ...

# %%
plt.figure(figsize = (15,8))
sns.barplot(data=countries_with_ranking_upto_5, x='Country', y='HappinessScore', hue='Year')

#Iceland, Denmark and Norway have consistently been ranked among the top 5 happiest countries in the world from 2015-2019
#Switzerland seems to have dropped down on it's ranking in 2019. It is not in the top 5 in the year 2019
#Finland seems to be ranked among the top 5 happy countries from 2016-2019. The happiness score for this country is increasing with each year
#Netherlands seems to be in the top 5 happy countries in the year 2019.

# %%
poorest_ranked_countries=data_final[data_final['HappinessRank']>=154]
poorest_ranked_countries
# Out:
#                       Country  HappinessRank  HappinessScore       GDP  \
# 153                    Rwanda            154           3.465  0.222080
# 154                     Benin            155           3.340  0.286650
# 155                     Syria            156           3.006  0.663200
# 156                   Burundi            157           2.905  0.015300
# 157                      Togo            158           2.839  0.208680
# 311               Afghanistan            154           3.360  0.382270
# 312                      Togo            155           3.303  0.281230
# 313                     Syria            156           3.069  0.747190
# 314                   Burundi            157           2.905  0.068310
# 468                   Burundi            154           2.905  0.091623
# 469  Central African Republic            155           2.693  0.000000
# 623               South Sudan            154           3.254  0.337000
# ...

# %%
plt.figure(figsize = (15,8))
sns.barplot(data=poorest_ranked_countries, x='Country', y='HappinessScore', hue='Year')

#Burundi seems to be consistently very low on it's ranking in terms of the hapiness score (from 2015-2018). However, the happiness ranking seems to have become higher in 2019 hence it is not visible in our graph

# %%
sns.pairplot(data_final, hue='Year')

# %% [markdown]
# # Creating a model

# %%
#Linear Regression Model

from sklearn.model_selection import train_test_split
from sklearn.linear_model import LinearRegression, Lasso, Ridge, LassoCV, BayesianRidge
import statsmodels.formula.api as sm
import matplotlib.pylab as plt
from dmba import regressionSummary, exhaustive_search
from dmba import backward_elimination, forward_selection, stepwise_selection
from dmba import adjusted_r2_score, AIC_score, BIC_score

# %%
data_final.head()
# Out:
#        Country  HappinessRank  HappinessScore      GDP   Family     Life  \
# 0  Switzerland              1           7.587  1.39651  1.34951  0.94143
# 1      Iceland              2           7.561  1.30232  1.40223  0.94784
# 2      Denmark              3           7.527  1.32548  1.36058  0.87464
# 3       Norway              4           7.522  1.45900  1.33095  0.88521
# 4       Canada              5           7.427  1.32629  1.32261  0.90563
#
#    Freedom    Trust  Generosity  Year
# 0  0.66557  0.41978     0.29678  2015
# 1  0.62877  0.14145     0.43630  2015
# 2  0.64938  0.48357     0.34139  2015
# 3  0.66973  0.36503     0.34699  2015
# 4  0.63297  0.32957     0.45811  2015

# %%
x=data_final.iloc[:,3:9] #The x variables are GDP, Family, Life, Freedom, Trust, Generosity
y=data_final['HappinessScore']

# %%
#Splitting the data into training and testing
X_train, X_test, y_train, y_test = train_test_split(x, y, test_size=0.4, random_state=9) #60% training, 40% testing

# %%
#Creating the Linear Regression model
lr = LinearRegression()
lr.fit(X_train, y_train)
# Out:
# LinearRegression(copy_X=True, fit_intercept=True, n_jobs=None, normalize=False)

# %%
print('intercept ', lr.intercept_)
print(pd.DataFrame({'Predictor': x.columns, 'coefficient': lr.coef_}))
print("\n*********************************************************\n")
regressionSummary(y_train, lr.predict(X_train))
y_pred = lr.predict(X_train)
print("*********************************************************\n")
print('adjusted r2 : ', adjusted_r2_score(y_train, y_pred, lr))
print('AIC : ', AIC_score(y_train, y_pred, lr))
print('BIC : ', BIC_score(y_train, y_pred, lr))
# Out:
# intercept  2.0926378913759973
#     Predictor  coefficient
# 0         GDP     1.186209
# 1      Family     0.741020
# 2        Life     0.960713
# 3     Freedom     1.295037
# 4       Trust     0.869019
# 5  Generosity     0.771580
#
# *********************************************************
#
#
# Regression statistics
#
#                       Mean Error (ME) : -0.0000
#        Root Mean Squared Error (RMSE) : 0.5284
#             Mean Absolute Error (MAE) : 0.4049
#           Mean Percentage Error (MPE) : -1.0650
# Mean Absolute Percentage Error (MAPE) : 8.0427
# *********************************************************
#
# adjusted r2 :  0.7857634399477388
# AIC :  748.6859055423848
# BIC :  781.890727689955

# %% [markdown]
# # Using unseen data to make predictions

# %% [markdown]
# From the graphs in the exploratory data analysis, we have understood the following:
# GDP Range: 0 to 2.096
#
# 1. As the GDP values get higher, the happiness score also becomes higher. ( countries with GDP of approx 1.2 or greater seem to have a higher happiness score)
# 2. As the Family values get higher, the happiness score also becomes higher. ( countries with GDP of approx 1 or greater seem to have a higher happiness score)
# 3. As the Life values get higher, the happiness score also becomes higher. ( countries with GDP of approx 0.8 or greater seem to have a higher happiness score)
# 4. As the Freedom values get higher, the happiness score also becomes higher. ( countries with Freedom of approx 0.35 or greater seem to have a higher happiness score)
# 5. Trust scores do not seem to be impacting Happiness scores to a great extent (countries with Trust of approx 0.1 to 0.2 seem to have a higher happiness score)
# 6. Generosity scores do not seem to be impacting Happiness scores to a great extent (countries with Generosity of approx 0.2 to 0.4 seem to have a higher happiness score)
#
#
# Note:
#
# 1. GDP Range: 0 to 2.096
# 2. Family Range of values: 0 to 1.64
# 3. Life Range of values: 0 to 1.141
# 4. Freedom Range of values: 0 to 0.7
# 5. Trust Range of values: 0 to 0.55
# 6. Generosity Range of values: 0 to 0.83

# %%
x.head()
# Out:
#        GDP   Family     Life  Freedom    Trust  Generosity
# 0  1.39651  1.34951  0.94143  0.66557  0.41978     0.29678
# 1  1.30232  1.40223  0.94784  0.62877  0.14145     0.43630
# 2  1.32548  1.36058  0.87464  0.64938  0.48357     0.34139
# 3  1.45900  1.33095  0.88521  0.66973  0.36503     0.34699
# 4  1.32629  1.32261  0.90563  0.63297  0.32957     0.45811

# %%
#Creating our own data from intuition
values_to_predict= np.array([
                            [1.8, 1.2, 1, 0.6, 0.15, 0.3],    # Case 1: Surely will have high happiness score
                            [0.3, 0.25,0.4, 0.11,0.1,0.11 ],  #Case 2: Surely will have low happiness score
                        ])

print(values_to_predict, '\n\n')
# Out:
# [[1.8  1.2  1.   0.6  0.15 0.3 ]
#  [0.3  0.25 0.4  0.11 0.1  0.11]]

# %%
print(lr.predict(values_to_predict))
# Out:
# [7.21660165 3.33227091]

# %% [markdown]
# ### Our predictions seem to be right!
# 1. The first result gives us a high happiness score of 7.21660165. This is true as per our own judgement and the result is what we expected it to be.
# 2. The second result gives us a low happiness score of 3.33227091. This is true as per our own judgement and the result is what we expected it to be.
